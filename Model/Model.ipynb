# %%
import numpy as np

# %%
X = np.load('X.npy')
y = np.load('Y.npy')
X.shape, y.shape
# Out:
# ((653712, 777), (653712, 32))

# %%
y1 = y[:, :8]
y2 = y[:, 8:16]
y3 = y[:, 16:24]
y4 = y[:, 24:]
print(y1.shape, y2.shape, y3.shape, y4.shape)
# Out:
# (653712, 8) (653712, 8) (653712, 8) (653712, 8)

# %%
from keras.models import Sequential
from keras.layers import Dense,Activation,Flatten,Dropout
from keras.callbacks import ModelCheckpoint
# Out:
# Using TensorFlow backend.

# %%
# from IPython.core.display import clear_output
# print(y1.shape)
# keras.layers.Conv2D(10, (3, 3), activation = 'relu', input_shape = (12, 8, 8)),
# keras.layers.MaxPooling2D(pool_size = (2, 2)),
# print("First Square: ")
# print("Column: ")
model_alpha1 = Sequential([
                            # keras.layers.Conv3D(10, (3, 1, 1), activation = 'relu', input_shape = (13, 8, 8, 1)),
                            # keras.layers.MaxPool3D((2, 1, 1)),
#                             Flatten(),
                            Dense(256, activation = 'relu'),
                            Dense(128, activation = 'relu'),
#                             Dropout(0.2),
                            Dense(64, activation = 'relu'),
                            Dropout(0.5),
                            Dense(8, activation = 'softmax')])

model_alpha1.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# clear_output()

# print("Row: ")
model_num1 = Sequential([  
                            # keras.layers.Conv3D(10, (3, 1, 1), activation = 'relu', input_shape = (13, 8, 8, 1)),
                            # keras.layers.MaxPool3D((2, 1, 1)),
#                             Flatten(input_shape = (773, 1)),
                            Dense(256, activation = 'relu'),
                            Dense(128, activation = 'relu'),
#                             Dropout(0.2),
                            Dense(64, activation = 'relu'),
                            Dropout(0.5),
                            Dense(8, activation = 'softmax')])

model_num1.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# print("Second Square: ")
# print("Column: ")
model_alpha2 = Sequential([
                            # keras.layers.Conv3D(10, (3, 1, 1), activation = 'relu', input_shape = (13, 8, 8, 1)),
                            # keras.layers.MaxPool3D((2, 1, 1)),
#                             Flatten(input_shape = (773, 1)),
                            Dense(256, activation = 'relu'),
                            Dense(128, activation = 'relu'),
#                             Dropout(0.2),
                            Dense(64, activation = 'relu'),
                            Dropout(0.5),
                            Dense(8, activation = 'softmax')])

model_alpha2.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# print("Row: ")
model_num2 = Sequential([ 
                            # keras.layers.Conv3D(10, (3, 1, 1), activation = 'relu', input_shape = (13, 8, 8, 1)),
                            # keras.layers.MaxPool3D((2, 1, 1)),
#                             Flatten(input_shape = (773, 1)),
                            Dense(256, activation = 'relu'),
                            Dense(128, activation = 'relu'),
#                             Dropout(0.2),
                            Dense(64, activation = 'relu'),
                            Dropout(0.5),
                            Dense(8, activation = 'softmax')])

model_num2.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# model_alpha1.add(keras.layers.Conv2D(10, (3, 3), activation = 'relu', input_shape = (12, 8, 8)))
# model_alpha1.add(keras.layers.MaxPooling2D(pool_size = (2, 2)))

# # model.add(keras.layers.Conv2D(10, (3, 3), activation = 'relu'))
# # model.add(keras.layers.MaxPooling2D(pool_size = (2, 2)))

# model_alpha1.add(keras.layers.Flatten())

# model_alpha1.add(keras.layers.Dense(128, activation = 'relu'))
# model_alpha1.add(keras.layers.Dense(128, activation = 'relu'))
# model_alpha1.add(keras.layers.Dense(32, activation = 'sigmoid'))

# %%
checkpoint1 = ModelCheckpoint('model__alpha1.model',monitor='val_loss',verbose=0,save_best_only=True,mode='auto')
checkpoint2 = ModelCheckpoint('model__num1.model',monitor='val_loss',verbose=0,save_best_only=True,mode='auto')
checkpoint3 = ModelCheckpoint('model__alpha2.model',monitor='val_loss',verbose=0,save_best_only=True,mode='auto')
checkpoint4 = ModelCheckpoint('model__num2.model',monitor='val_loss',verbose=0,save_best_only=True,mode='auto')

# %%
# model_num2.fit(X[:n//reps], y4[:n//reps], batch_size = 256, epochs = 5, validation_split = 0.1)
# model_num2.fit(X[n//reps:2*n//reps], y4[n//reps:2*n//reps], batch_size = 256, epochs = 5, validation_split = 0.1)
# model_num2.fit(X[2*n//reps:3*n//reps], y4[2*n//reps:3*n//reps], batch_size = 256, epochs = 5, validation_split = 0.1)
# model_num2.fit(X[3*n//reps:], y4[3*n//reps:], batch_size = 256, epochs = 5, validation_split = 0.1)

# history1 = model_alpha1.fit(X, y1, batch_size = 2048, epochs = 10, callbacks = [checkpoint1], validation_split = 0.1)
# history2 = model_num1.fit(X, y2, batch_size = 2048, epochs = 10, callbacks = [checkpoint2], validation_split = 0.1)
history3 = model_alpha2.fit(X, y3, batch_size = 2048, epochs = 10, callbacks = [checkpoint3], validation_split = 0.1)
# history4 = model_num2.fit(X, y4, batch_size = 2048, epochs = 10, callbacks = [checkpoint4], validation_split = 0.1)
# Out:
# Train on 588340 samples, validate on 65372 samples
# Epoch 1/10
# 588340/588340 [==============================] - 38s 64us/step - loss: 1.9265 - accuracy: 0.2339 - val_loss: 1.8613 - val_accuracy: 0.2711
# Epoch 2/10
# 588340/588340 [==============================] - 16s 27us/step - loss: 1.8047 - accuracy: 0.3036 - val_loss: 1.7717 - val_accuracy: 0.3215
# Epoch 3/10
# 588340/588340 [==============================] - 14s 24us/step - loss: 1.7259 - accuracy: 0.3460 - val_loss: 1.7366 - val_accuracy: 0.3404
# Epoch 4/10
# 588340/588340 [==============================] - 14s 23us/step - loss: 1.6803 - accuracy: 0.3665 - val_loss: 1.7221 - val_accuracy: 0.3459
# Epoch 5/10
# 588340/588340 [==============================] - 14s 25us/step - loss: 1.6468 - accuracy: 0.3802 - val_loss: 1.7216 - val_accuracy: 0.3489
# Epoch 6/10
# 588340/588340 [==============================] - 15s 25us/step - loss: 1.6214 - accuracy: 0.3906 - val_loss: 1.7164 - val_accuracy: 0.3504
# Epoch 7/10
# ...

# %%
import matplotlib.pyplot as plt
# Out:
# Bad key "text.kerning_factor" on line 4 in
# C:\Users\ANIKET\miniconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution

# %%
plt.plot(history1.history['val_loss'], label = 'val_loss')
plt.plot(history1.history['loss'], label = 'loss')
plt.legend()
plt.title('Model Alpha 1')
# Out:
# Text(0.5, 1.0, 'Model Alpha 1')

# %%
plt.plot(history1.history['val_accuracy'], label = 'val_accuracy')
plt.plot(history1.history['accuracy'], label = 'accuracy')
plt.legend()
plt.title('Model Alpha 1')
# Out:
# Text(0.5, 1.0, 'Model Alpha 1')

# %%
plt.plot(history2.history['val_loss'], label = 'val_loss')
plt.plot(history2.history['loss'], label = 'loss')
plt.legend()
plt.title('Model Num 1')
# Out:
# Text(0.5, 1.0, 'Model Num 1')

# %%
plt.plot(history2.history['val_accuracy'], label = 'val_accuracy')
plt.plot(history2.history['accuracy'], label = 'accuracy')
plt.legend()
plt.title('Model Num 1')
# Out:
# Text(0.5, 1.0, 'Model Num 1')

# %%
plt.plot(history3.history['val_loss'], label = 'val_loss')
plt.plot(history3.history['loss'], label = 'loss')
plt.legend()
plt.title('Model Alpha 2')
# Out:
# Text(0.5, 1.0, 'Model Alpha 2')

# %%
plt.plot(history3.history['val_accuracy'], label = 'val_accuracy')
plt.plot(history3.history['accuracy'], label = 'accuracy')
plt.legend()
plt.title('Model Alpha 2')
# Out:
# Text(0.5, 1.0, 'Model Alpha 2')

# %%
plt.plot(history4.history['val_loss'], label = 'val_loss')
plt.plot(history4.history['loss'], label = 'loss')
plt.legend()
plt.title('Model Num 2')
# Out:
# Text(0.5, 1.0, 'Model Num 2')

# %%
plt.plot(history4.history['val_accuracy'], label = 'val_accuracy')
plt.plot(history4.history['accuracy'], label = 'accuracy')
plt.legend()
plt.title('Model Num 2')
# Out:
# Text(0.5, 1.0, 'Model Num 2')
